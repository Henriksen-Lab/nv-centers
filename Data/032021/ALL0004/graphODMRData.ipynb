# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import vco

pd.options.display.max_rows = 100

# %%
csvCh1 = "./F0004CH1.CSV"
csvCh2 = "./F0004CH2.CSV"


columnNames = ["Parameter", "Value", "Empty", "X", "Y", "NaN"]
ch1 = pd.read_csv(csvCh1, names=columnNames)
ch2 = pd.read_csv(csvCh2, names=columnNames)

csvSet = "./F0004TEK.SET"

settingsColumns = ["Parameter", "Value"]
settings = pd.read_csv(csvSet, delimiter=" ", lineterminator=";",names=settingsColumns)

# %%
print("Settings:")
print(settings)
print(("Other parameters:"))
print(ch1.Parameter,ch2.Value)
print(ch2.Parameter)
print("Raw Data")
print(ch1.Y)
print(ch2.Y)
# Out:
# Settings:
#                              Parameter      Value
# 0                      :DISPLAY:FORMAT         YT
# 1                                STYLE    VECTORS
# 2                          PERSISTENCE          0
# 3                        :ACQUIRE:MODE    AVERAGE
# 4                               NUMAVG        128
# 5                                STATE          1
# 6                            STOPAFTER    RUNSTOP
# 7                           :CH1:PROBE      1.0E0
# 8                         CURRENTPROBE      1.0E1
# 9                                SCALE     7.0E-3
# 10                            POSITION   -9.192E1
# 11                            COUPLING         DC
# 12                           BANDWIDTH        OFF
# 13                              INVERT        OFF
# 14                               YUNIT          V
# 15                          :CH2:PROBE      1.0E0
# 16                        CURRENTPROBE      1.0E1
# 17                               SCALE     6.0E-2
# 18                            POSITION    -4.16E0
# 19                            COUPLING         AC
# 20                           BANDWIDTH        OFF
# 21                              INVERT        OFF
# 22                               YUNIT          V
# 23                    :HORIZONTAL:VIEW       MAIN
# 24                          MAIN:SCALE     2.5E-4
# 25                            POSITION   1.196E-1
# 26             :HORIZONTAL:DELAY:SCALE     2.5E-4
# 27                            POSITION   1.196E-1
# 28                   :HORIZONTAL:SCALE     2.5E-4
# 29                  :TRIGGER:MAIN:MODE     NORMAL
# 30                                TYPE       EDGE
# 31                       HOLDOFF:VALUE     5.0E-7
# 32           :TRIGGER:MAIN:EDGE:SOURCE        EXT
# 33                            COUPLING         DC
# 34                               SLOPE       RISE
# 35            :TRIGGER:MAIN:VIDEO:SYNC      FIELD
# 36                            POLARITY     NORMAL
# 37                                LINE          1
# 38                            STANDARD       NTSC
# 39  :TRIGGER:MAIN:PULSE:WIDTH:POLARITY   POSITIVE
# 40                                WHEN    OUTSIDE
# 41                               WIDTH  8.0706E-3
# 42                 :TRIGGER:MAIN:LEVEL    1.472E0
# 43                         :SELECT:CH1          1
# 44                                 CH2          1
# 45                                MATH          0
# 46                                REFA          0
# 47                                REFB          0
# 48                    :CURSOR:FUNCTION      VBARS
# 49                       SELECT:SOURCE        CH2
# 50                 :CURSOR:VBARS:UNITS    SECONDS
# 51                           POSITION1  1.1904E-1
# 52                           POSITION2  1.2036E-1
# 53             :CURSOR:HBARS:POSITION1   2.208E-1
# 54                           POSITION2    1.92E-1
# 55               :DATALOGGING:DURATION         30
# 56                              SOURCE        CH1
# 57             :MEASUREMENT:MEAS1:TYPE       MEAN
# 58                              SOURCE        CH1
# 59             :MEASUREMENT:MEAS2:TYPE    MINIMUM
# 60                              SOURCE        CH2
# 61             :MEASUREMENT:MEAS3:TYPE    MAXIMUM
# 62                              SOURCE        CH2
# 63             :MEASUREMENT:MEAS4:TYPE      PK2PK
# 64                              SOURCE        CH2
# 65             :MEASUREMENT:MEAS5:TYPE    MINIMUM
# 66                              SOURCE        CH1
# 67                 :MEASUREMENT:METHOD       AUTO
# 68                        :MATH:DEFINE  CH1 - CH2
# 69                   VERTICAL:POSITION      0.0E0
# 70                               SCALE     5.0E-2
# 71       :MATH:FFT:HORIZONTAL:POSITION      5.0E1
# 72                               SCALE      1.0E0
# 73         :MATH:FFT:VERTICAL:POSITION      0.0E0
# 74                               SCALE      1.0E0
# 75                 :AUTORANGE:SETTINGS       BOTH
# 76                       :LIMIT:SOURCE        CH1
# 77                             COMPARE       REFA
# 78                           SAVEIMAGE          0
# 79                             SAVEWFM          0
# 80                      STOPAFTER:MODE     MANUAL
# 81         :LIMIT:TEMPLATE:DESTINATION       REFA
# 82                              SOURCE        CH1
# 83                TOLERANCE:HORIZONTAL          0
# 84                            VERTICAL        0\n
# Other parameters:
# 0         Record Length
# 1       Sample Interval
# 2         Trigger Point
# 3                   NaN
# 4                   NaN
#              ...
# 2495                NaN
# 2496                NaN
# 2497                NaN
# 2498                NaN
# 2499                NaN
# Name: Parameter, Length: 2500, dtype: object 0              2.500000e+03
# 1              1.000000e-06
# 2       -1.183500000000e+05
# 3                       NaN
# 4                       NaN
#                ...
# 2495                    NaN
# 2496                    NaN
# 2497                    NaN
# 2498                    NaN
# 2499                    NaN
# Name: Value, Length: 2500, dtype: object
# 0         Record Length
# 1       Sample Interval
# 2         Trigger Point
# 3                   NaN
# 4                   NaN
#              ...
# 2495                NaN
# 2496                NaN
# 2497                NaN
# 2498                NaN
# 2499                NaN
# Name: Parameter, Length: 2500, dtype: object
# Raw Data
# 0       0.66416
# 1       0.66416
# 2       0.66388
# 3       0.66388
# 4       0.66388
#          ...
# 2495    0.66444
# 2496    0.66444
# 2497    0.66444
# 2498    0.66472
# 2499    0.66444
# Name: Y, Length: 2500, dtype: float64
# 0       0.0024
# 1       0.0000
# 2       0.0000
# 3       0.0024
# 4       0.0024
#          ...
# 2495    0.4776
# 2496    0.4800
# 2497    0.4776
# 2498    0.4800
# 2499    0.4800
# Name: Y, Length: 2500, dtype: float64

# %%
ch2.Y=ch2.Y+7.5
microwaves = vco.voltageToFrequency(ch2.Y)
normalizedIntensity = ch1.Y/np.amax(ch1.Y)

# %%
plt.scatter(ch2.Y,ch1.Y,s=4)
plt.title("Intensity vs Vtune")
plt.xlabel("Voltage")
plt.ylabel("Intensity")
plt.grid()
plt.show()

# %%
plt.scatter(microwaves,ch1.Y,s=4)
plt.title("NV Center ZFS Spectra B=0")
plt.xlabel("Microwaves (GHz)")
plt.ylabel("Intensity (V)")
plt.grid()
plt.show()

# %%
plt.scatter(microwaves,normalizedIntensity,s=4)
plt.title("NV Center ZFS Spectra B=0")
plt.xlabel("Microwaves (GHz)")
plt.ylabel("Normalized Intensity")
plt.grid()
plt.show()

# %%
plt.plot(ch2.X,ch2.Y)
plt.title("Vtune vs Time")
plt.xlabel("Time")
plt.ylabel("Vtune")
plt.grid()

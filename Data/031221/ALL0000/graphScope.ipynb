# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
csvCh1 = "./F0000CH1.CSV"
csvCh2 = "./F0000CH2.CSV"

# %%
columnNames = ["Parameters","Value","Empty","X","Y","NaN"]
ch1 = pd.read_csv(csvCh1,names=columnNames)
ch2 = pd.read_csv(csvCh2,names=columnNames)
print(ch1)
# Out:
#            Parameters                Value  Empty        X        Y  NaN
# 0       Record Length         2.500000e+03    NaN  0.03738  0.36108  NaN
# 1     Sample Interval         1.000000e-05    NaN  0.03739  0.36108  NaN
# 2       Trigger Point  -3.738000000000e+03    NaN  0.03740  0.36096  NaN
# 3                 NaN                  NaN    NaN  0.03741  0.36108  NaN
# 4                 NaN                  NaN    NaN  0.03742  0.36108  NaN
# ...               ...                  ...    ...      ...      ...  ...
# 2495              NaN                  NaN    NaN  0.06233  0.36120  NaN
# 2496              NaN                  NaN    NaN  0.06234  0.36132  NaN
# 2497              NaN                  NaN    NaN  0.06235  0.36120  NaN
# 2498              NaN                  NaN    NaN  0.06236  0.36120  NaN
# 2499              NaN                  NaN    NaN  0.06237  0.36132  NaN
#
# [2500 rows x 6 columns]

# %%
plt.scatter(ch2.Y,ch1.Y,s=4)
plt.title("Intensity vs Vtune")
plt.xlabel("Voltage")
plt.ylabel("Intensity")
plt.grid()
plt.show()

# %%
plt.plot(ch2.X,ch2.Y)
plt.title("Vtune vs Time")
plt.xlabel("Time")
plt.ylabel("Vtune")
plt.grid()

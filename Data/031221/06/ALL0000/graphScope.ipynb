# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
csvCh1 = "./F0000CH1.CSV"
csvCh2 = "./F0000CH2.CSV"

# %%
columnNames = ["Parameters","Value","Empty","X","Y","NaN"]
ch1 = pd.read_csv(csvCh1,names=columnNames)
ch2 = pd.read_csv(csvCh2,names=columnNames)
print(ch1)
# Out:
#            Parameters                Value  Empty        X        Y  NaN
# 0       Record Length         2.500000e+03    NaN  0.03710  0.36828  NaN
# 1     Sample Interval         1.000000e-05    NaN  0.03711  0.36816  NaN
# 2       Trigger Point  -3.710000000000e+03    NaN  0.03712  0.36816  NaN
# 3                 NaN                  NaN    NaN  0.03713  0.36816  NaN
# 4                 NaN                  NaN    NaN  0.03714  0.36816  NaN
# ...               ...                  ...    ...      ...      ...  ...
# 2495              NaN                  NaN    NaN  0.06205  0.36624  NaN
# 2496              NaN                  NaN    NaN  0.06206  0.36612  NaN
# 2497              NaN                  NaN    NaN  0.06207  0.36612  NaN
# 2498              NaN                  NaN    NaN  0.06208  0.36612  NaN
# 2499              NaN                  NaN    NaN  0.06209  0.36600  NaN
#
# [2500 rows x 6 columns]

# %%
plt.scatter(ch2.Y,ch1.Y,s=4)
plt.title("Intensity vs Vtune")
plt.xlabel("Intensity")
plt.ylabel("Voltage")
plt.grid()
plt.show()

# %%
plt.plot(ch2.X,ch2.Y)
plt.title("Vtune vs Time")
plt.xlabel("Time")
plt.ylabel("Vtune")
plt.grid()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
csvCh1 = "./F0000CH1.CSV"
csvCh2 = "./F0000CH2.CSV"

# %%
columnNames = ["Parameters","Value","Empty","X","Y","NaN"]
ch1 = pd.read_csv(csvCh1,names=columnNames)
ch2 = pd.read_csv(csvCh2,names=columnNames)
print(ch1)
# Out:
#            Parameters                Value  Empty        X        Y  NaN
# 0       Record Length         2.500000e+03    NaN  0.07640  1.54380  NaN
# 1     Sample Interval         1.000000e-05    NaN  0.07641  1.54380  NaN
# 2       Trigger Point  -7.640000000000e+03    NaN  0.07642  1.54380  NaN
# 3                 NaN                  NaN    NaN  0.07643  1.54380  NaN
# 4                 NaN                  NaN    NaN  0.07644  1.54392  NaN
# ...               ...                  ...    ...      ...      ...  ...
# 2495              NaN                  NaN    NaN  0.10135  1.54596  NaN
# 2496              NaN                  NaN    NaN  0.10136  1.54608  NaN
# 2497              NaN                  NaN    NaN  0.10137  1.54608  NaN
# 2498              NaN                  NaN    NaN  0.10138  1.54608  NaN
# 2499              NaN                  NaN    NaN  0.10139  1.54608  NaN
#
# [2500 rows x 6 columns]

# %%
plt.scatter(ch2.Y,ch1.Y,s=4)
plt.title("Intensity vs Vtune")
plt.xlabel("Intensity")
plt.ylabel("Voltage")
plt.grid()
plt.show()

# %%
plt.plot(ch2.X,ch2.Y)
plt.title("Vtune vs Time")
plt.xlabel("Time")
plt.ylabel("Vtune")
plt.grid()

# %%
bits = 8
levels = 2**bits
sens = 2
divs = 8
voltsPerLevel = sens*divs/levels
print(voltsPerLevel)
# Out:
# 0.0625

# %%
0.08*levels
# Out:
# 20.48

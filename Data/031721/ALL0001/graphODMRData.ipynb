# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import vco

pd.options.display.max_rows = 100

# %%
csvCh1 = "./F0001CH1.CSV"
csvCh2 = "./F0001CH2.CSV"


columnNames = ["Parameter", "Value", "Empty", "X", "Y", "NaN"]
ch1 = pd.read_csv(csvCh1, names=columnNames)
ch2 = pd.read_csv(csvCh2, names=columnNames)

csvSet = "./F0001TEK.SET"

settingsColumns = ["Parameter", "Value"]
settings = pd.read_csv(csvSet, delimiter=" ", lineterminator=";",names=settingsColumns)

# %%
print("Settings:")
print(settings)
print(("Other parameters:"))
print(ch1.Parameter,ch2.Value)
print(ch2.Parameter)
print("Raw Data")
print(ch1.Y)
print(ch2.Y)
# Out:
# Settings:
#                              Parameter      Value
# 0                      :DISPLAY:FORMAT         YT
# 1                                STYLE    VECTORS
# 2                          PERSISTENCE          0
# 3                        :ACQUIRE:MODE    AVERAGE
# 4                               NUMAVG        128
# 5                                STATE          1
# 6                            STOPAFTER    RUNSTOP
# 7                           :CH1:PROBE      1.0E0
# 8                         CURRENTPROBE      1.0E1
# 9                                SCALE     6.0E-3
# 10                            POSITION   -8.752E1
# 11                            COUPLING         DC
# 12                           BANDWIDTH        OFF
# 13                              INVERT        OFF
# 14                               YUNIT          V
# 15                          :CH2:PROBE      1.0E0
# 16                        CURRENTPROBE      1.0E1
# 17                               SCALE    2.04E-1
# 18                            POSITION   -3.724E1
# 19                            COUPLING         DC
# 20                           BANDWIDTH        OFF
# 21                              INVERT        OFF
# 22                               YUNIT          V
# 23                    :HORIZONTAL:VIEW       MAIN
# 24                          MAIN:SCALE     5.0E-4
# 25                            POSITION   8.044E-2
# 26             :HORIZONTAL:DELAY:SCALE     2.5E-4
# 27                            POSITION   8.104E-2
# 28                   :HORIZONTAL:SCALE     5.0E-4
# 29                  :TRIGGER:MAIN:MODE       AUTO
# 30                                TYPE       EDGE
# 31                       HOLDOFF:VALUE     5.0E-7
# 32           :TRIGGER:MAIN:EDGE:SOURCE        EXT
# 33                            COUPLING         DC
# 34                               SLOPE       RISE
# 35            :TRIGGER:MAIN:VIDEO:SYNC      FIELD
# 36                            POLARITY     NORMAL
# 37                                LINE          1
# 38                            STANDARD       NTSC
# 39  :TRIGGER:MAIN:PULSE:WIDTH:POLARITY   POSITIVE
# 40                                WHEN    OUTSIDE
# 41                               WIDTH  8.0706E-3
# 42                 :TRIGGER:MAIN:LEVEL    1.472E0
# 43                         :SELECT:CH1          1
# 44                                 CH2          1
# 45                                MATH          0
# 46                                REFA          0
# 47                                REFB          0
# 48                    :CURSOR:FUNCTION      VBARS
# 49                       SELECT:SOURCE        CH2
# 50                 :CURSOR:VBARS:UNITS    SECONDS
# 51                           POSITION1   8.054E-2
# 52                           POSITION2   8.092E-2
# 53             :CURSOR:HBARS:POSITION1  7.49904E0
# 54                           POSITION2  7.40112E0
# 55               :DATALOGGING:DURATION         30
# 56                              SOURCE        CH1
# 57             :MEASUREMENT:MEAS1:TYPE       MEAN
# 58                              SOURCE        CH1
# 59             :MEASUREMENT:MEAS2:TYPE    MINIMUM
# 60                              SOURCE        CH2
# 61             :MEASUREMENT:MEAS3:TYPE    MAXIMUM
# 62                              SOURCE        CH2
# 63             :MEASUREMENT:MEAS4:TYPE      PK2PK
# 64                              SOURCE        CH2
# 65             :MEASUREMENT:MEAS5:TYPE  FREQUENCY
# 66                              SOURCE        CH2
# 67                 :MEASUREMENT:METHOD       AUTO
# 68                        :MATH:DEFINE  CH1 - CH2
# 69                   VERTICAL:POSITION      0.0E0
# 70                               SCALE     2.0E-1
# 71       :MATH:FFT:HORIZONTAL:POSITION      5.0E1
# 72                               SCALE      1.0E0
# 73         :MATH:FFT:VERTICAL:POSITION      0.0E0
# 74                               SCALE      1.0E0
# 75                 :AUTORANGE:SETTINGS       BOTH
# 76                       :LIMIT:SOURCE        CH1
# 77                             COMPARE       REFA
# 78                           SAVEIMAGE          0
# 79                             SAVEWFM          0
# 80                      STOPAFTER:MODE     MANUAL
# 81         :LIMIT:TEMPLATE:DESTINATION       REFA
# 82                              SOURCE        CH1
# 83                TOLERANCE:HORIZONTAL          0
# 84                            VERTICAL        0\n
# Other parameters:
# 0         Record Length
# 1       Sample Interval
# 2         Trigger Point
# 3                   NaN
# 4                   NaN
#              ...
# 2495                NaN
# 2496                NaN
# 2497                NaN
# 2498                NaN
# 2499                NaN
# Name: Parameter, Length: 2500, dtype: object 0              2.500000e+03
# 1              2.000000e-06
# 2       -3.897000000000e+04
# 3                       NaN
# 4                       NaN
#                ...
# 2495                    NaN
# 2496                    NaN
# 2497                    NaN
# 2498                    NaN
# 2499                    NaN
# Name: Value, Length: 2500, dtype: object
# 0         Record Length
# 1       Sample Interval
# 2         Trigger Point
# 3                   NaN
# 4                   NaN
#              ...
# 2495                NaN
# 2496                NaN
# 2497                NaN
# 2498                NaN
# 2499                NaN
# Name: Parameter, Length: 2500, dtype: object
# Raw Data
# 0       0.54456
# 1       0.54456
# 2       0.54456
# 3       0.54456
# 4       0.54456
#          ...
# 2495    0.54528
# 2496    0.54528
# 2497    0.54552
# 2498    0.54528
# 2499    0.54552
# Name: Y, Length: 2500, dtype: float64
# 0       7.1808
# 1       7.1808
# 2       7.1808
# 3       7.1808
# 4       7.1808
#          ...
# 2495    7.9968
# 2496    7.9968
# 2497    7.9968
# 2498    7.9968
# 2499    7.9968
# Name: Y, Length: 2500, dtype: float64

# %%
microwaves = vco.voltageToFrequency(ch2.Y)
normalizedIntensity = ch1.Y/np.amax(ch1.Y)

# %%
plt.scatter(ch2.Y,ch1.Y,s=4)
plt.title("Intensity vs Vtune")
plt.xlabel("Voltage")
plt.ylabel("Intensity")
plt.grid()
plt.show()

# %%
plt.scatter(microwaves,ch1.Y,s=4)
plt.title("NV Center ZFS Spectra B=0")
plt.xlabel("Microwaves (GHz)")
plt.ylabel("Intensity (V)")
plt.grid()
plt.show()

# %%
plt.scatter(microwaves,normalizedIntensity,s=4)
plt.title("NV Center ZFS Spectra B=0")
plt.xlabel("Microwaves (GHz)")
plt.ylabel("Normalized Intensity")
plt.grid()
plt.show()

# %%
plt.plot(ch2.X,ch2.Y)
plt.title("Vtune vs Time")
plt.xlabel("Time")
plt.ylabel("Vtune")
plt.grid()
